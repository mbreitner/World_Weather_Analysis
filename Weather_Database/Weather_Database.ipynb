# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
#Import Requests
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e9b953928c58fce60b6f8dace00361b7

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #Run an API request for each of the cites 
    try:
    #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
     #Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
    #Append the city information into city_data list
        city_data.append({'City': city.title(),
                        'Lat': city_lat, 
                        'Lng': city_lng, 
                        'Max Temp': city_max_temp, 
                        'Humidity': city_humidity, 
                        'Cloudiness': city_clouds, 
                        'Wind Speed': city_wind, 
                        'Country': city_country, 
                        'Current Description': city_description})
    
#If an error is experienced, skip the city
    except: 
        print("City not found. Skipping...")
        pass
#Indicate that the Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arman
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | cervo
# Processing Record 8 of Set 1 | shingu
# Processing Record 9 of Set 1 | salalah
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | santa marta
# Processing Record 12 of Set 1 | acajutla
# Processing Record 13 of Set 1 | najran
# Processing Record 14 of Set 1 | sisophon
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | voznesenye
# Processing Record 17 of Set 1 | russell
# Processing Record 18 of Set 1 | rantepao
# Processing Record 19 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 1 | codrington
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | rocha
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | namibe
# Processing Record 25 of Set 1 | aporawan
# City not found. Skipping...
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | kendari
# Processing Record 28 of Set 1 | catuday
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | katangli
# Processing Record 41 of Set 1 | aykhal
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | touros
# Processing Record 44 of Set 1 | sisimiut
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | orlik
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | vaovai
# City not found. Skipping...
# Processing Record 49 of Set 1 | ormara
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | zhuhai
# Processing Record 2 of Set 2 | gresham
# Processing Record 3 of Set 2 | coquimbo
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | karratha
# Processing Record 10 of Set 2 | los llanos de aridane
# Processing Record 11 of Set 2 | pecos
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | yen bai
# Processing Record 14 of Set 2 | whitehorse
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | novyy svit
# Processing Record 17 of Set 2 | portland
# Processing Record 18 of Set 2 | itarema
# Processing Record 19 of Set 2 | nagato
# Processing Record 20 of Set 2 | antofagasta
# Processing Record 21 of Set 2 | wamba
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | talnakh
# Processing Record 25 of Set 2 | mayumba
# Processing Record 26 of Set 2 | ancud
# Processing Record 27 of Set 2 | superior
# Processing Record 28 of Set 2 | narsaq
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | vao
# Processing Record 32 of Set 2 | glenluce
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | matara
# Processing Record 36 of Set 2 | sladkovo
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | socorro
# Processing Record 39 of Set 2 | oistins
# Processing Record 40 of Set 2 | witu
# Processing Record 41 of Set 2 | charlestown
# Processing Record 42 of Set 2 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 43 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 2 | taylorville
# Processing Record 45 of Set 2 | burns lake
# Processing Record 46 of Set 2 | tabuk
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | redcar
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | arang
# Processing Record 2 of Set 3 | radha kund
# Processing Record 3 of Set 3 | rapid valley
# Processing Record 4 of Set 3 | tilichiki
# Processing Record 5 of Set 3 | teguldet
# Processing Record 6 of Set 3 | fairbanks
# Processing Record 7 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 3 | lorengau
# Processing Record 9 of Set 3 | mount gambier
# Processing Record 10 of Set 3 | yarim
# Processing Record 11 of Set 3 | kyabe
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | mandapam
# Processing Record 14 of Set 3 | san patricio
# Processing Record 15 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | shimoda
# Processing Record 18 of Set 3 | bluff
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | doka
# Processing Record 21 of Set 3 | belmonte
# Processing Record 22 of Set 3 | beloha
# Processing Record 23 of Set 3 | torbay
# Processing Record 24 of Set 3 | berlevag
# Processing Record 25 of Set 3 | pisco
# Processing Record 26 of Set 3 | muhos
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | kaitangata
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | saint-pierre
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | oktyabrskiy
# Processing Record 33 of Set 3 | port lincoln
# Processing Record 34 of Set 3 | san cristobal
# Processing Record 35 of Set 3 | oxbow
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | yulara
# Processing Record 38 of Set 3 | pekan
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 3 | melipilla
# Processing Record 42 of Set 3 | santa vitoria do palmar
# Processing Record 43 of Set 3 | tual
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | vasylivka
# Processing Record 46 of Set 3 | yanchukan
# City not found. Skipping...
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | bermejo
# Processing Record 49 of Set 3 | rosario oeste
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | port hardy
# Processing Record 3 of Set 4 | nome
# Processing Record 4 of Set 4 | beringovskiy
# Processing Record 5 of Set 4 | visby
# Processing Record 6 of Set 4 | lac du bonnet
# Processing Record 7 of Set 4 | klaksvik
# Processing Record 8 of Set 4 | miquelon
# Processing Record 9 of Set 4 | lavrentiya
# Processing Record 10 of Set 4 | hobart
# Processing Record 11 of Set 4 | elko
# Processing Record 12 of Set 4 | bundaberg
# Processing Record 13 of Set 4 | nikolskoye
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | derzhavinsk
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | baruun-urt
# Processing Record 18 of Set 4 | yumen
# Processing Record 19 of Set 4 | luderitz
# Processing Record 20 of Set 4 | magnolia
# Processing Record 21 of Set 4 | bandarbeyla
# Processing Record 22 of Set 4 | chokwe
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | kaliua
# Processing Record 25 of Set 4 | jumla
# Processing Record 26 of Set 4 | korem
# Processing Record 27 of Set 4 | ray
# Processing Record 28 of Set 4 | rawson
# Processing Record 29 of Set 4 | altay
# Processing Record 30 of Set 4 | provideniya
# Processing Record 31 of Set 4 | san jose
# Processing Record 32 of Set 4 | diffa
# Processing Record 33 of Set 4 | san quintin
# Processing Record 34 of Set 4 | oussouye
# Processing Record 35 of Set 4 | nuevo progreso
# Processing Record 36 of Set 4 | namatanai
# Processing Record 37 of Set 4 | anamur
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | port moresby
# Processing Record 40 of Set 4 | toyooka
# Processing Record 41 of Set 4 | kawalu
# Processing Record 42 of Set 4 | san juan
# Processing Record 43 of Set 4 | sibolga
# Processing Record 44 of Set 4 | upington
# Processing Record 45 of Set 4 | noyon
# Processing Record 46 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 4 | aloleng
# Processing Record 48 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 4 | roald
# Processing Record 50 of Set 4 | vardo
# Processing Record 1 of Set 5 | koygorodok
# Processing Record 2 of Set 5 | hualmay
# Processing Record 3 of Set 5 | buala
# Processing Record 4 of Set 5 | ahipara
# Processing Record 5 of Set 5 | muros
# Processing Record 6 of Set 5 | quito
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | bethel
# Processing Record 9 of Set 5 | oum hadjer
# Processing Record 10 of Set 5 | tampakan
# Processing Record 11 of Set 5 | ginir
# Processing Record 12 of Set 5 | cairns
# Processing Record 13 of Set 5 | letterkenny
# Processing Record 14 of Set 5 | neiafu
# Processing Record 15 of Set 5 | tefe
# Processing Record 16 of Set 5 | upernavik
# Processing Record 17 of Set 5 | shadegan
# Processing Record 18 of Set 5 | kodiak
# Processing Record 19 of Set 5 | kirakira
# Processing Record 20 of Set 5 | bud
# Processing Record 21 of Set 5 | comodoro rivadavia
# Processing Record 22 of Set 5 | yellowknife
# Processing Record 23 of Set 5 | mehamn
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | zabol
# Processing Record 26 of Set 5 | vidim
# Processing Record 27 of Set 5 | pueblo
# Processing Record 28 of Set 5 | cedar city
# Processing Record 29 of Set 5 | jonkoping
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 32 of Set 5 | saint-francois
# Processing Record 33 of Set 5 | roma
# Processing Record 34 of Set 5 | broome
# Processing Record 35 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 5 | chekhov
# Processing Record 37 of Set 5 | viedma
# Processing Record 38 of Set 5 | nemuro
# Processing Record 39 of Set 5 | kurikka
# Processing Record 40 of Set 5 | saint-joseph
# Processing Record 41 of Set 5 | saldanha
# Processing Record 42 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 43 of Set 5 | carnaiba
# Processing Record 44 of Set 5 | waipawa
# Processing Record 45 of Set 5 | avera
# Processing Record 46 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 5 | altamont
# Processing Record 48 of Set 5 | mogadishu
# Processing Record 49 of Set 5 | pokrovsk
# Processing Record 50 of Set 5 | sudbury
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | asmara
# Processing Record 3 of Set 6 | teguise
# Processing Record 4 of Set 6 | katherine
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | moissala
# Processing Record 7 of Set 6 | norton shores
# Processing Record 8 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 6 | salinopolis
# Processing Record 10 of Set 6 | panjab
# Processing Record 11 of Set 6 | naze
# Processing Record 12 of Set 6 | ascension
# Processing Record 13 of Set 6 | rupert
# Processing Record 14 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 6 | sesori
# Processing Record 17 of Set 6 | alappuzha
# Processing Record 18 of Set 6 | tabou
# Processing Record 19 of Set 6 | aswan
# Processing Record 20 of Set 6 | matamoros
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | ponta delgada
# Processing Record 23 of Set 6 | sao jose da coroa grande
# Processing Record 24 of Set 6 | inta
# Processing Record 25 of Set 6 | quatre cocos
# Processing Record 26 of Set 6 | versalles
# Processing Record 27 of Set 6 | urumqi
# Processing Record 28 of Set 6 | cherskiy
# Processing Record 29 of Set 6 | sayat
# Processing Record 30 of Set 6 | kot addu
# Processing Record 31 of Set 6 | esperance
# Processing Record 32 of Set 6 | tabasalu
# Processing Record 33 of Set 6 | buraydah
# Processing Record 34 of Set 6 | valparaiso
# Processing Record 35 of Set 6 | langsa
# Processing Record 36 of Set 6 | meulaboh
# Processing Record 37 of Set 6 | fuling
# Processing Record 38 of Set 6 | magadan
# Processing Record 39 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 40 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 6 | camden
# Processing Record 42 of Set 6 | port blair
# Processing Record 43 of Set 6 | douentza
# Processing Record 44 of Set 6 | pechenga
# Processing Record 45 of Set 6 | goderich
# Processing Record 46 of Set 6 | cienaga
# Processing Record 47 of Set 6 | acapulco
# Processing Record 48 of Set 6 | marsh harbour
# Processing Record 49 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 50 of Set 6 | utica
# Processing Record 1 of Set 7 | dongsheng
# Processing Record 2 of Set 7 | luau
# Processing Record 3 of Set 7 | portree
# Processing Record 4 of Set 7 | constitucion
# Processing Record 5 of Set 7 | hamilton
# Processing Record 6 of Set 7 | hambantota
# Processing Record 7 of Set 7 | cooma
# Processing Record 8 of Set 7 | safaga
# Processing Record 9 of Set 7 | komsomolskiy
# Processing Record 10 of Set 7 | marawi
# Processing Record 11 of Set 7 | arzachena
# Processing Record 12 of Set 7 | padang
# Processing Record 13 of Set 7 | aleysk
# Processing Record 14 of Set 7 | verkhnevilyuysk
# Processing Record 15 of Set 7 | nabire
# Processing Record 16 of Set 7 | conakry
# Processing Record 17 of Set 7 | kruisfontein
# Processing Record 18 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 20 of Set 7 | ulu tiram
# Processing Record 21 of Set 7 | saint-augustin
# Processing Record 22 of Set 7 | saint george
# Processing Record 23 of Set 7 | gizo
# Processing Record 24 of Set 7 | pasni
# Processing Record 25 of Set 7 | banda aceh
# Processing Record 26 of Set 7 | khani
# Processing Record 27 of Set 7 | kahului
# Processing Record 28 of Set 7 | missungwi
# Processing Record 29 of Set 7 | tiarei
# Processing Record 30 of Set 7 | tete
# Processing Record 31 of Set 7 | havoysund
# Processing Record 32 of Set 7 | qui nhon
# Processing Record 33 of Set 7 | kushmurun
# Processing Record 34 of Set 7 | batemans bay
# Processing Record 35 of Set 7 | khvorostyanka
# Processing Record 36 of Set 7 | caravelas
# Processing Record 37 of Set 7 | bowen
# Processing Record 38 of Set 7 | boddam
# Processing Record 39 of Set 7 | great yarmouth
# Processing Record 40 of Set 7 | fortuna
# Processing Record 41 of Set 7 | monroe
# Processing Record 42 of Set 7 | northam
# Processing Record 43 of Set 7 | westport
# Processing Record 44 of Set 7 | dauphin
# Processing Record 45 of Set 7 | lourdes
# Processing Record 46 of Set 7 | popesti-leordeni
# Processing Record 47 of Set 7 | birnin kebbi
# Processing Record 48 of Set 7 | keuruu
# Processing Record 49 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 7 | lasa
# Processing Record 1 of Set 8 | konya
# Processing Record 2 of Set 8 | puerto rico
# Processing Record 3 of Set 8 | tarusan
# Processing Record 4 of Set 8 | yar-sale
# Processing Record 5 of Set 8 | amla
# Processing Record 6 of Set 8 | rio blanco
# Processing Record 7 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 8 | aden
# Processing Record 9 of Set 8 | yaan
# Processing Record 10 of Set 8 | san agustin
# Processing Record 11 of Set 8 | olinda
# Processing Record 12 of Set 8 | egvekinot
# Processing Record 13 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 8 | kongolo
# Processing Record 15 of Set 8 | idukki
# Processing Record 16 of Set 8 | sandakan
# Processing Record 17 of Set 8 | aklavik
# Processing Record 18 of Set 8 | sabang
# Processing Record 19 of Set 8 | araceli
# Processing Record 20 of Set 8 | ketchikan
# Processing Record 21 of Set 8 | mayo
# Processing Record 22 of Set 8 | luwuk
# Processing Record 23 of Set 8 | ternate
# Processing Record 24 of Set 8 | baghmara
# Processing Record 25 of Set 8 | lakatoro
# Processing Record 26 of Set 8 | tasiilaq
# Processing Record 27 of Set 8 | warrington
# Processing Record 28 of Set 8 | chuy
# Processing Record 29 of Set 8 | kysyl-syr
# Processing Record 30 of Set 8 | sam chuk
# Processing Record 31 of Set 8 | longyearbyen
# Processing Record 32 of Set 8 | fort nelson
# Processing Record 33 of Set 8 | prince rupert
# Processing Record 34 of Set 8 | gat
# Processing Record 35 of Set 8 | antalaha
# Processing Record 36 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 8 | batticaloa
# Processing Record 38 of Set 8 | xichang
# Processing Record 39 of Set 8 | lima
# Processing Record 40 of Set 8 | blyth
# Processing Record 41 of Set 8 | te anau
# Processing Record 42 of Set 8 | lompoc
# Processing Record 43 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 44 of Set 8 | bambanglipuro
# Processing Record 45 of Set 8 | parintins
# Processing Record 46 of Set 8 | podor
# Processing Record 47 of Set 8 | oliver
# Processing Record 48 of Set 8 | grindavik
# Processing Record 49 of Set 8 | vestmannaeyjar
# Processing Record 50 of Set 8 | axim
# Processing Record 1 of Set 9 | bontang
# Processing Record 2 of Set 9 | kabanga
# Processing Record 3 of Set 9 | berdigestyakh
# Processing Record 4 of Set 9 | champerico
# Processing Record 5 of Set 9 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 6 of Set 9 | dwarka
# Processing Record 7 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 9 | velizh
# Processing Record 9 of Set 9 | carnot
# Processing Record 10 of Set 9 | teknaf
# Processing Record 11 of Set 9 | morki
# Processing Record 12 of Set 9 | san policarpo
# Processing Record 13 of Set 9 | cartagena
# Processing Record 14 of Set 9 | laguna
# Processing Record 15 of Set 9 | balkanabat
# Processing Record 16 of Set 9 | haines junction
# Processing Record 17 of Set 9 | ambon
# Processing Record 18 of Set 9 | terrace
# Processing Record 19 of Set 9 | temnikov
# Processing Record 20 of Set 9 | buluang
# Processing Record 21 of Set 9 | katsuura
# Processing Record 22 of Set 9 | codajas
# Processing Record 23 of Set 9 | sao felix do xingu
# Processing Record 24 of Set 9 | nago
# Processing Record 25 of Set 9 | byron bay
# Processing Record 26 of Set 9 | balabac
# Processing Record 27 of Set 9 | dingle
# Processing Record 28 of Set 9 | aguimes
# Processing Record 29 of Set 9 | maniitsoq
# Processing Record 30 of Set 9 | lencois paulista
# Processing Record 31 of Set 9 | clyde river
# Processing Record 32 of Set 9 | cookeville
# Processing Record 33 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 9 | mulege
# Processing Record 35 of Set 9 | harper
# Processing Record 36 of Set 9 | dunda
# Processing Record 37 of Set 9 | sheoganj
# Processing Record 38 of Set 9 | iracoubo
# Processing Record 39 of Set 9 | bangassou
# Processing Record 40 of Set 9 | bafra
# Processing Record 41 of Set 9 | winnemucca
# Processing Record 42 of Set 9 | manggar
# Processing Record 43 of Set 9 | sinnamary
# Processing Record 44 of Set 9 | santiago
# Processing Record 45 of Set 9 | marzuq
# Processing Record 46 of Set 9 | gorontalo
# Processing Record 47 of Set 9 | guadalupe
# Processing Record 48 of Set 9 | bubaque
# Processing Record 49 of Set 9 | sitka
# Processing Record 50 of Set 9 | palaikastron
# Processing Record 1 of Set 10 | arenapolis
# Processing Record 2 of Set 10 | yeppoon
# Processing Record 3 of Set 10 | mumford
# Processing Record 4 of Set 10 | awjilah
# Processing Record 5 of Set 10 | richards bay
# Processing Record 6 of Set 10 | henties bay
# Processing Record 7 of Set 10 | wonthaggi
# Processing Record 8 of Set 10 | coihaique
# Processing Record 9 of Set 10 | springdale
# Processing Record 10 of Set 10 | birjand
# Processing Record 11 of Set 10 | isangel
# Processing Record 12 of Set 10 | kieta
# Processing Record 13 of Set 10 | kashan
# Processing Record 14 of Set 10 | iqaluit
# Processing Record 15 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 16 of Set 10 | valera
# Processing Record 17 of Set 10 | pangnirtung
# Processing Record 18 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 10 | noumea
# Processing Record 20 of Set 10 | conde
# Processing Record 21 of Set 10 | broken hill
# Processing Record 22 of Set 10 | pemex
# Processing Record 23 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 24 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 10 | piacabucu
# Processing Record 26 of Set 10 | muslyumovo
# Processing Record 27 of Set 10 | coulihaut
# City not found. Skipping...
# Processing Record 28 of Set 10 | verkhniy avzyan
# Processing Record 29 of Set 10 | verkhoyansk
# Processing Record 30 of Set 10 | santa fe
# Processing Record 31 of Set 10 | kelvington
# Processing Record 32 of Set 10 | north bend
# Processing Record 33 of Set 10 | warwick
# Processing Record 34 of Set 10 | basud
# Processing Record 35 of Set 10 | rosetta
# Processing Record 36 of Set 10 | kabare
# Processing Record 37 of Set 10 | ha tinh
# Processing Record 38 of Set 10 | tuktoyaktuk
# Processing Record 39 of Set 10 | punta alta
# Processing Record 40 of Set 10 | kushiro
# Processing Record 41 of Set 10 | boyolangu
# Processing Record 42 of Set 10 | palmer
# Processing Record 43 of Set 10 | homer
# Processing Record 44 of Set 10 | krasnokholm
# Processing Record 45 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 46 of Set 10 | smithers
# Processing Record 47 of Set 10 | emerald
# Processing Record 48 of Set 10 | zheleznodorozhnyy
# Processing Record 49 of Set 10 | wanning
# Processing Record 50 of Set 10 | zalantun
# Processing Record 1 of Set 11 | tabas
# Processing Record 2 of Set 11 | saint anthony
# Processing Record 3 of Set 11 | mount isa
# Processing Record 4 of Set 11 | anchorage
# Processing Record 5 of Set 11 | chulumani
# Processing Record 6 of Set 11 | ambalema
# Processing Record 7 of Set 11 | mocuba
# Processing Record 8 of Set 11 | marrakesh
# Processing Record 9 of Set 11 | longonjo
# Processing Record 10 of Set 11 | kluczbork
# Processing Record 11 of Set 11 | vetluzhskiy
# Processing Record 12 of Set 11 | banswada
# Processing Record 13 of Set 11 | iwade
# Processing Record 14 of Set 11 | plettenberg bay
# Processing Record 15 of Set 11 | andenes
# Processing Record 16 of Set 11 | pacific grove
# Processing Record 17 of Set 11 | brenham
# Processing Record 18 of Set 11 | labuan
# Processing Record 19 of Set 11 | iquique
# Processing Record 20 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 11 | capelinha
# Processing Record 22 of Set 11 | airai
# Processing Record 23 of Set 11 | atar
# Processing Record 24 of Set 11 | vanimo
# Processing Record 25 of Set 11 | vila franca do campo
# Processing Record 26 of Set 11 | norman wells
# Processing Record 27 of Set 11 | nitra
# Processing Record 28 of Set 11 | hervey bay
# Processing Record 29 of Set 11 | alofi
# Processing Record 30 of Set 11 | soe
# Processing Record 31 of Set 11 | pemangkat
# Processing Record 32 of Set 11 | ornskoldsvik
# Processing Record 33 of Set 11 | avanigadda
# Processing Record 34 of Set 11 | metro
# Processing Record 35 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 36 of Set 11 | wuzhou
# Processing Record 37 of Set 11 | monrovia
# Processing Record 38 of Set 11 | karaman
# Processing Record 39 of Set 11 | dukat
# Processing Record 40 of Set 11 | victoria point
# Processing Record 41 of Set 11 | foumbot
# Processing Record 42 of Set 11 | kijang
# Processing Record 43 of Set 11 | mahibadhoo
# Processing Record 44 of Set 11 | raga
# Processing Record 45 of Set 11 | tokuyama
# Processing Record 46 of Set 11 | belaya gora
# Processing Record 47 of Set 11 | bafq
# Processing Record 48 of Set 11 | takoradi
# Processing Record 49 of Set 11 | gambela
# Processing Record 50 of Set 11 | wiarton
# Processing Record 1 of Set 12 | uige
# Processing Record 2 of Set 12 | kulhudhuffushi
# Processing Record 3 of Set 12 | sioux lookout
# Processing Record 4 of Set 12 | uk
# City not found. Skipping...
# Processing Record 5 of Set 12 | clinton
# Processing Record 6 of Set 12 | svetlaya
# Processing Record 7 of Set 12 | ayan
# Processing Record 8 of Set 12 | hengyang
# Processing Record 9 of Set 12 | kizukuri
# Processing Record 10 of Set 12 | moratuwa
# Processing Record 11 of Set 12 | itoman
# Processing Record 12 of Set 12 | manali
# Processing Record 13 of Set 12 | songjianghe
# Processing Record 14 of Set 12 | roebourne
# Processing Record 15 of Set 12 | mayna
# Processing Record 16 of Set 12 | daru
# Processing Record 17 of Set 12 | faanui
# Processing Record 18 of Set 12 | sept-iles
# Processing Record 19 of Set 12 | souillac
# Processing Record 20 of Set 12 | custoias
# Processing Record 21 of Set 12 | maragogi
# Processing Record 22 of Set 12 | ciudad bolivar
# Processing Record 23 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 24 of Set 12 | bambous virieux
# Processing Record 25 of Set 12 | trairi
# Processing Record 26 of Set 12 | ketchenery
# City not found. Skipping...
# Processing Record 27 of Set 12 | salamanca
# Processing Record 28 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 12 | lugovskiy
# City not found. Skipping...
# Processing Record 30 of Set 12 | salina cruz
# Processing Record 31 of Set 12 | susanville
# Processing Record 32 of Set 12 | dapaong
# Processing Record 33 of Set 12 | tura
# Processing Record 34 of Set 12 | korop
# Processing Record 35 of Set 12 | cap-aux-meules
# Processing Record 36 of Set 12 | sorland
# Processing Record 37 of Set 12 | nebbi
# Processing Record 38 of Set 12 | dunedin
# Processing Record 39 of Set 12 | nantucket
# Processing Record 40 of Set 12 | marovoay
# Processing Record 41 of Set 12 | blagoyevo
# Processing Record 42 of Set 12 | maicao
# Processing Record 43 of Set 12 | gamba
# Processing Record 44 of Set 12 | gwadar
# Processing Record 45 of Set 12 | ransang
# Processing Record 46 of Set 12 | palauig
# Processing Record 47 of Set 12 | anadyr
# Processing Record 48 of Set 12 | noyabrsk
# Processing Record 49 of Set 12 | kavaratti
# Processing Record 50 of Set 12 | husavik
# Processing Record 1 of Set 13 | iwaki
# Processing Record 2 of Set 13 | ropczyce
# Processing Record 3 of Set 13 | boulder
# Processing Record 4 of Set 13 | maceio
# Processing Record 5 of Set 13 | huarmey
# Processing Record 6 of Set 13 | camacha
# Processing Record 7 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 8 of Set 13 | arlit
# Processing Record 9 of Set 13 | olafsvik
# Processing Record 10 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 11 of Set 13 | leningradskiy
# Processing Record 12 of Set 13 | cangucu
# Processing Record 13 of Set 13 | half moon bay
# Processing Record 14 of Set 13 | uaua
# Processing Record 15 of Set 13 | mount darwin
# Processing Record 16 of Set 13 | ribas do rio pardo
# Processing Record 17 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 18 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 13 | college
# Processing Record 20 of Set 13 | miri
# Processing Record 21 of Set 13 | kununurra
# Processing Record 22 of Set 13 | maku
# Processing Record 23 of Set 13 | tupik
# Processing Record 24 of Set 13 | kawambwa
# Processing Record 25 of Set 13 | moose factory
# Processing Record 26 of Set 13 | sciacca
# Processing Record 27 of Set 13 | sovetskiy
# Processing Record 28 of Set 13 | bathurst
# Processing Record 29 of Set 13 | zyryanka
# Processing Record 30 of Set 13 | lukulu
# Processing Record 31 of Set 13 | basco
# Processing Record 32 of Set 13 | moindou
# Processing Record 33 of Set 13 | shieli
# Processing Record 34 of Set 13 | bafoulabe
# Processing Record 35 of Set 13 | seoul
# Processing Record 36 of Set 13 | yerbogachen
# Processing Record 37 of Set 13 | olavarria
# Processing Record 38 of Set 13 | makat
# Processing Record 39 of Set 13 | kadoma
# Processing Record 40 of Set 13 | benguela
# Processing Record 41 of Set 13 | port hedland
# Processing Record 42 of Set 13 | gorodishche
# Processing Record 43 of Set 13 | ryotsu
# Processing Record 44 of Set 13 | rafai
# Processing Record 45 of Set 13 | breves
# Processing Record 46 of Set 13 | nador
# Processing Record 47 of Set 13 | faya
# Processing Record 48 of Set 13 | sebastian
# Processing Record 49 of Set 13 | cidreira
# Processing Record 50 of Set 13 | lata
# Processing Record 1 of Set 14 | pringsewu
# Processing Record 2 of Set 14 | baykit
# Processing Record 3 of Set 14 | pangody
# Processing Record 4 of Set 14 | yerofey pavlovich
# Processing Record 5 of Set 14 | coleraine
# Processing Record 6 of Set 14 | sicamous
# Processing Record 7 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 14 | chalchihuites
# Processing Record 9 of Set 14 | qasigiannguit
# Processing Record 10 of Set 14 | santa rosa
# Processing Record 11 of Set 14 | bacolod
# Processing Record 12 of Set 14 | kanchanaburi
# Processing Record 13 of Set 14 | gillette
# Processing Record 14 of Set 14 | santa cruz
# Processing Record 15 of Set 14 | cayenne
# Processing Record 16 of Set 14 | buchanan
# Processing Record 17 of Set 14 | progreso
# Processing Record 18 of Set 14 | banjar
# Processing Record 19 of Set 14 | pandamatenga
# Processing Record 20 of Set 14 | sur
# Processing Record 21 of Set 14 | trat
# Processing Record 22 of Set 14 | ghugus
# Processing Record 23 of Set 14 | bereda
# Processing Record 24 of Set 14 | novyy urengoy
# Processing Record 25 of Set 14 | sol-iletsk
# Processing Record 26 of Set 14 | bolshaya vishera
# City not found. Skipping...
# Processing Record 27 of Set 14 | chunskiy
# Processing Record 28 of Set 14 | rostovka
# Processing Record 29 of Set 14 | bismarck
# Processing Record 30 of Set 14 | atka
# City not found. Skipping...
# Processing Record 31 of Set 14 | ballina
# Processing Record 32 of Set 14 | manaus
# Processing Record 33 of Set 14 | balikpapan
# Processing Record 34 of Set 14 | sung noen
# Processing Record 35 of Set 14 | kristiinankaupunki
# Processing Record 36 of Set 14 | adwa
# Processing Record 37 of Set 14 | tsiroanomandidy
# Processing Record 38 of Set 14 | torva
# Processing Record 39 of Set 14 | naantali
# Processing Record 40 of Set 14 | nouadhibou
# Processing Record 41 of Set 14 | rumuruti
# Processing Record 42 of Set 14 | suntar
# Processing Record 43 of Set 14 | dickinson
# Processing Record 44 of Set 14 | ulkan
# Processing Record 45 of Set 14 | evensk
# Processing Record 46 of Set 14 | kindu
# Processing Record 47 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 14 | boralday
# Processing Record 49 of Set 14 | la asuncion
# Processing Record 50 of Set 14 | piat
# Processing Record 1 of Set 15 | wilmington
# Processing Record 2 of Set 15 | waingapu
# Processing Record 3 of Set 15 | bama
# Processing Record 4 of Set 15 | brae
# Processing Record 5 of Set 15 | tukrah
# Processing Record 6 of Set 15 | flinders
# Processing Record 7 of Set 15 | sungai padi
# Processing Record 8 of Set 15 | kupang
# Processing Record 9 of Set 15 | bilibino
# Processing Record 10 of Set 15 | columbia
# Processing Record 11 of Set 15 | kitimat
# Processing Record 12 of Set 15 | toktogul
# Processing Record 13 of Set 15 | sosnovo-ozerskoye
# Processing Record 14 of Set 15 | srednekolymsk
# Processing Record 15 of Set 15 | jutai
# Processing Record 16 of Set 15 | msanga
# Processing Record 17 of Set 15 | sydney
# Processing Record 18 of Set 15 | sabha
# Processing Record 19 of Set 15 | nelson bay
# Processing Record 20 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 15 | businga
# Processing Record 22 of Set 15 | hami
# Processing Record 23 of Set 15 | aksu
# Processing Record 24 of Set 15 | riyadh
# Processing Record 25 of Set 15 | tairua
# Processing Record 26 of Set 15 | lincoln
# Processing Record 27 of Set 15 | mizan teferi
# Processing Record 28 of Set 15 | bakel
# Processing Record 29 of Set 15 | rathenow
# Processing Record 30 of Set 15 | saint-leu
# Processing Record 31 of Set 15 | oytal
# Processing Record 32 of Set 15 | finschhafen
# Processing Record 33 of Set 15 | esmeraldas
# Processing Record 34 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 15 | jalu
# Processing Record 36 of Set 15 | bagan
# Processing Record 37 of Set 15 | tautira
# Processing Record 38 of Set 15 | teahupoo
# Processing Record 39 of Set 15 | samarai
# Processing Record 40 of Set 15 | sukhaya buyvola
# Processing Record 41 of Set 15 | joshimath
# Processing Record 42 of Set 15 | goundam
# Processing Record 43 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 44 of Set 15 | bermeo
# Processing Record 45 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 15 | itaituba
# Processing Record 47 of Set 15 | hofn
# Processing Record 48 of Set 15 | mana
# Processing Record 49 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 15 | namtsy
# Processing Record 1 of Set 16 | jaguariaiva
# Processing Record 2 of Set 16 | mitu
# Processing Record 3 of Set 16 | altamira
# Processing Record 4 of Set 16 | pasighat
# Processing Record 5 of Set 16 | sawtell
# Processing Record 6 of Set 16 | ajaccio
# Processing Record 7 of Set 16 | san rafael
# Processing Record 8 of Set 16 | oktyabrskoye
# Processing Record 9 of Set 16 | malbork
# Processing Record 10 of Set 16 | arkhangelsk
# Processing Record 11 of Set 16 | wanaka
# Processing Record 12 of Set 16 | ajdabiya
# Processing Record 13 of Set 16 | savinka
# Processing Record 14 of Set 16 | haapiti
# Processing Record 15 of Set 16 | horki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Arman  59.7000  150.1667     54.95        93          99
# 1       Carnarvon -24.8667  113.6333     59.07        67          80
# 2    Ponta Do Sol  32.6667  -17.1000     73.71        74           1
# 3  Severo-Kurilsk  50.6789  156.1250     55.22        93          94
# 4       Busselton -33.6500  115.3333     48.09        61          99
# 5         Mataura -46.1927  168.8643     41.49        85          41
# 6           Cervo  43.6702   -7.4101     66.20        81           2
# 7          Shingu  33.7333  135.9833     75.90        88          81
# 8         Salalah  17.0151   54.0924     77.09       100          90
# 9           Kapaa  22.0752 -159.3190     82.72        70          75
#
#    Wind Speed Country      Current Description
# 0        1.59      RU          overcast clouds
# 1       12.66      AU            broken clouds
# 2        6.93      PT                clear sky
# 3        7.29      RU          overcast clouds
# 4       14.50      AU          overcast clouds
# 5        3.31      NZ         scattered clouds
# 6       11.70      ES                clear sky
# 7        4.63      JP            broken clouds
# 8        6.91      OM  light intensity drizzle
# 9        3.00      US               light rain

# %%
# import the dataframe to a CSV
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
