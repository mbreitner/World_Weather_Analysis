# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
#Import Requests
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e9b953928c58fce60b6f8dace00361b7

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #Run an API request for each of the cites 
    try:
    #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
     #Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
    #Append the city information into city_data list
        city_data.append({'City': city.title(),
                        'Lat': city_lat, 
                        'Lng': city_lng, 
                        'Max Temp': city_max_temp, 
                        'Humidity': city_humidity, 
                        'Cloudiness': city_clouds, 
                        'Wind Speed': city_wind, 
                        'Country': city_country, 
                        'Current Description': city_description})
    
#If an error is experienced, skip the city
    except: 
        print("City not found. Skipping...")
        pass
#Indicate that the Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | smithers
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | semirom
# Processing Record 4 of Set 1 | san patricio
# Processing Record 5 of Set 1 | guatire
# Processing Record 6 of Set 1 | banda aceh
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | bairiki
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | lima
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | umm bab
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | hambantota
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | tubuala
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | anupgarh
# Processing Record 31 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | manta
# Processing Record 34 of Set 1 | vardo
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | tupik
# Processing Record 41 of Set 1 | mount isa
# Processing Record 42 of Set 1 | kenai
# Processing Record 43 of Set 1 | pochutla
# Processing Record 44 of Set 1 | santa rosalia
# Processing Record 45 of Set 1 | namatanai
# Processing Record 46 of Set 1 | santa marta
# Processing Record 47 of Set 1 | heidenreichstein
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | pinega
# Processing Record 50 of Set 1 | erenhot
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | ulladulla
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | illapel
# Processing Record 5 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 2 | mehamn
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | kimbe
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | nanortalik
# Processing Record 13 of Set 2 | amuntai
# Processing Record 14 of Set 2 | matara
# Processing Record 15 of Set 2 | husavik
# Processing Record 16 of Set 2 | mingshui
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | christchurch
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | burica
# City not found. Skipping...
# Processing Record 22 of Set 2 | kuminskiy
# Processing Record 23 of Set 2 | bandar
# Processing Record 24 of Set 2 | pevek
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | honningsvag
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | san joaquin
# Processing Record 31 of Set 2 | tanah merah
# Processing Record 32 of Set 2 | talnakh
# Processing Record 33 of Set 2 | souillac
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | pedro carbo
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | namibe
# Processing Record 39 of Set 2 | srednekolymsk
# Processing Record 40 of Set 2 | yeppoon
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | sao joao da barra
# Processing Record 44 of Set 2 | fare
# Processing Record 45 of Set 2 | conceicao do araguaia
# Processing Record 46 of Set 2 | jiuquan
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | acapulco
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | sur
# Processing Record 2 of Set 3 | port hedland
# Processing Record 3 of Set 3 | college
# Processing Record 4 of Set 3 | amazar
# Processing Record 5 of Set 3 | bulaevo
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | faya
# Processing Record 8 of Set 3 | bengkulu
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | skeldon
# Processing Record 12 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 3 | springbok
# Processing Record 14 of Set 3 | fukue
# Processing Record 15 of Set 3 | buala
# Processing Record 16 of Set 3 | puerto palomas
# Processing Record 17 of Set 3 | amparai
# City not found. Skipping...
# Processing Record 18 of Set 3 | manaure
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | saldanha
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | honiara
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | vila franca do campo
# Processing Record 25 of Set 3 | nome
# Processing Record 26 of Set 3 | rafaela
# Processing Record 27 of Set 3 | aporawan
# City not found. Skipping...
# Processing Record 28 of Set 3 | pangnirtung
# Processing Record 29 of Set 3 | laguna
# Processing Record 30 of Set 3 | puerto escondido
# Processing Record 31 of Set 3 | rawson
# Processing Record 32 of Set 3 | severodvinsk
# Processing Record 33 of Set 3 | port alfred
# Processing Record 34 of Set 3 | hobyo
# Processing Record 35 of Set 3 | broome
# Processing Record 36 of Set 3 | davidson
# Processing Record 37 of Set 3 | ust-nera
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | cody
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | santiago
# Processing Record 42 of Set 3 | shellbrook
# Processing Record 43 of Set 3 | katsuura
# Processing Record 44 of Set 3 | geraldton
# Processing Record 45 of Set 3 | rudbar
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | torbay
# Processing Record 48 of Set 3 | voloshka
# Processing Record 49 of Set 3 | avera
# Processing Record 50 of Set 3 | ahipara
# Processing Record 1 of Set 4 | guliston
# Processing Record 2 of Set 4 | olafsvik
# Processing Record 3 of Set 4 | eatonton
# Processing Record 4 of Set 4 | maldonado
# Processing Record 5 of Set 4 | san cristobal
# Processing Record 6 of Set 4 | sisimiut
# Processing Record 7 of Set 4 | sakaiminato
# Processing Record 8 of Set 4 | scalloway
# City not found. Skipping...
# Processing Record 9 of Set 4 | borlange
# City not found. Skipping...
# Processing Record 10 of Set 4 | kadaura
# Processing Record 11 of Set 4 | gabu
# Processing Record 12 of Set 4 | manado
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | henties bay
# Processing Record 15 of Set 4 | kilindoni
# Processing Record 16 of Set 4 | dongsheng
# Processing Record 17 of Set 4 | westport
# Processing Record 18 of Set 4 | newala
# Processing Record 19 of Set 4 | jacmel
# Processing Record 20 of Set 4 | san carlos de bariloche
# Processing Record 21 of Set 4 | hagi
# Processing Record 22 of Set 4 | hayden
# Processing Record 23 of Set 4 | sangar
# Processing Record 24 of Set 4 | gimbi
# Processing Record 25 of Set 4 | tonk
# Processing Record 26 of Set 4 | saint-michel-des-saints
# Processing Record 27 of Set 4 | salas
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | ampanihy
# Processing Record 30 of Set 4 | tessalit
# Processing Record 31 of Set 4 | heihe
# Processing Record 32 of Set 4 | la ronge
# Processing Record 33 of Set 4 | aldan
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | wajir
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | am timan
# Processing Record 38 of Set 4 | kalmunai
# Processing Record 39 of Set 4 | coos bay
# Processing Record 40 of Set 4 | chambas
# Processing Record 41 of Set 4 | port elizabeth
# Processing Record 42 of Set 4 | itea
# Processing Record 43 of Set 4 | taranagar
# Processing Record 44 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 4 | gonaives
# Processing Record 46 of Set 4 | praia
# Processing Record 47 of Set 4 | ravar
# Processing Record 48 of Set 4 | leningradskiy
# Processing Record 49 of Set 4 | bud
# Processing Record 50 of Set 4 | belvidere
# Processing Record 1 of Set 5 | nikolskoye
# Processing Record 2 of Set 5 | powell
# Processing Record 3 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 5 | sawakin
# Processing Record 5 of Set 5 | ullapool
# Processing Record 6 of Set 5 | tambopata
# Processing Record 7 of Set 5 | kapaa
# Processing Record 8 of Set 5 | phan thiet
# Processing Record 9 of Set 5 | orda
# Processing Record 10 of Set 5 | vanimo
# Processing Record 11 of Set 5 | tulun
# Processing Record 12 of Set 5 | we
# City not found. Skipping...
# Processing Record 13 of Set 5 | oro valley
# Processing Record 14 of Set 5 | morondava
# Processing Record 15 of Set 5 | caxito
# Processing Record 16 of Set 5 | yellowknife
# Processing Record 17 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 5 | amarwara
# Processing Record 19 of Set 5 | tautira
# Processing Record 20 of Set 5 | touros
# Processing Record 21 of Set 5 | pocinhos
# Processing Record 22 of Set 5 | nizhniy odes
# Processing Record 23 of Set 5 | asau
# Processing Record 24 of Set 5 | jandaia do sul
# Processing Record 25 of Set 5 | iquique
# Processing Record 26 of Set 5 | vanavara
# Processing Record 27 of Set 5 | quatre cocos
# Processing Record 28 of Set 5 | takhtamygda
# Processing Record 29 of Set 5 | ribeira grande
# Processing Record 30 of Set 5 | stornoway
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | leshukonskoye
# Processing Record 33 of Set 5 | riyadh
# Processing Record 34 of Set 5 | ocos
# Processing Record 35 of Set 5 | valparaiso
# Processing Record 36 of Set 5 | kruisfontein
# Processing Record 37 of Set 5 | kawalu
# Processing Record 38 of Set 5 | bambous virieux
# Processing Record 39 of Set 5 | yerbogachen
# Processing Record 40 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | ponta do sol
# Processing Record 43 of Set 5 | haines junction
# Processing Record 44 of Set 5 | metsavan
# Processing Record 45 of Set 5 | rio grande
# Processing Record 46 of Set 5 | warmbad
# Processing Record 47 of Set 5 | solnechnyy
# Processing Record 48 of Set 5 | belmonte
# Processing Record 49 of Set 5 | turkan
# Processing Record 50 of Set 5 | sainte-claire
# Processing Record 1 of Set 6 | kaitangata
# Processing Record 2 of Set 6 | newport
# Processing Record 3 of Set 6 | lebu
# Processing Record 4 of Set 6 | luganville
# Processing Record 5 of Set 6 | caconda
# Processing Record 6 of Set 6 | saint anthony
# Processing Record 7 of Set 6 | paita
# Processing Record 8 of Set 6 | byron bay
# Processing Record 9 of Set 6 | goundam
# Processing Record 10 of Set 6 | severo-kurilsk
# Processing Record 11 of Set 6 | balta
# Processing Record 12 of Set 6 | ambon
# Processing Record 13 of Set 6 | alyangula
# Processing Record 14 of Set 6 | irupi
# Processing Record 15 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 6 | itoman
# Processing Record 17 of Set 6 | tromso
# Processing Record 18 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 19 of Set 6 | wilmington
# Processing Record 20 of Set 6 | bressuire
# Processing Record 21 of Set 6 | tepla
# Processing Record 22 of Set 6 | strezhevoy
# Processing Record 23 of Set 6 | turtkul
# City not found. Skipping...
# Processing Record 24 of Set 6 | tilichiki
# Processing Record 25 of Set 6 | arman
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | brae
# Processing Record 28 of Set 6 | north bend
# Processing Record 29 of Set 6 | manggar
# Processing Record 30 of Set 6 | palmer
# Processing Record 31 of Set 6 | cervo
# Processing Record 32 of Set 6 | wellington
# Processing Record 33 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 6 | kedrovyy
# Processing Record 35 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 6 | svetlyy
# Processing Record 37 of Set 6 | moose factory
# Processing Record 38 of Set 6 | rawlins
# Processing Record 39 of Set 6 | miri
# Processing Record 40 of Set 6 | uthal
# Processing Record 41 of Set 6 | mezen
# Processing Record 42 of Set 6 | azare
# Processing Record 43 of Set 6 | provideniya
# Processing Record 44 of Set 6 | baie-comeau
# Processing Record 45 of Set 6 | shimoda
# Processing Record 46 of Set 6 | kiama
# Processing Record 47 of Set 6 | jurm
# Processing Record 48 of Set 6 | iqaluit
# Processing Record 49 of Set 6 | bathsheba
# Processing Record 50 of Set 6 | codajas
# Processing Record 1 of Set 7 | san luis
# Processing Record 2 of Set 7 | barentu
# Processing Record 3 of Set 7 | troitskoye
# Processing Record 4 of Set 7 | prince rupert
# Processing Record 5 of Set 7 | goderich
# Processing Record 6 of Set 7 | borovoy
# Processing Record 7 of Set 7 | chuy
# Processing Record 8 of Set 7 | wahiawa
# Processing Record 9 of Set 7 | kununurra
# Processing Record 10 of Set 7 | concepcion
# Processing Record 11 of Set 7 | cidreira
# Processing Record 12 of Set 7 | havre-saint-pierre
# Processing Record 13 of Set 7 | bubaque
# Processing Record 14 of Set 7 | poum
# Processing Record 15 of Set 7 | sherlovaya gora
# Processing Record 16 of Set 7 | poindimie
# Processing Record 17 of Set 7 | neiafu
# Processing Record 18 of Set 7 | san quintin
# Processing Record 19 of Set 7 | cairns
# Processing Record 20 of Set 7 | fortuna
# Processing Record 21 of Set 7 | kahului
# Processing Record 22 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 24 of Set 7 | gat
# Processing Record 25 of Set 7 | villanueva
# Processing Record 26 of Set 7 | batemans bay
# Processing Record 27 of Set 7 | qasigiannguit
# Processing Record 28 of Set 7 | borbon
# Processing Record 29 of Set 7 | worland
# Processing Record 30 of Set 7 | khandbari
# Processing Record 31 of Set 7 | domoni
# Processing Record 32 of Set 7 | beloha
# Processing Record 33 of Set 7 | zapolyarnyy
# Processing Record 34 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 7 | areosa
# Processing Record 36 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | novyye burasy
# Processing Record 39 of Set 7 | dhola
# Processing Record 40 of Set 7 | belaya gora
# Processing Record 41 of Set 7 | sungairaya
# Processing Record 42 of Set 7 | umea
# Processing Record 43 of Set 7 | sinegorye
# Processing Record 44 of Set 7 | iskateley
# Processing Record 45 of Set 7 | sept-iles
# Processing Record 46 of Set 7 | kapoeta
# Processing Record 47 of Set 7 | tual
# Processing Record 48 of Set 7 | hokitika
# Processing Record 49 of Set 7 | omboue
# Processing Record 50 of Set 7 | kristiansund
# Processing Record 1 of Set 8 | gravdal
# Processing Record 2 of Set 8 | bonavista
# Processing Record 3 of Set 8 | umm lajj
# Processing Record 4 of Set 8 | florianopolis
# Processing Record 5 of Set 8 | nong han
# Processing Record 6 of Set 8 | inhambane
# Processing Record 7 of Set 8 | faanui
# Processing Record 8 of Set 8 | ambilobe
# Processing Record 9 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 8 | yenagoa
# Processing Record 11 of Set 8 | abu samrah
# Processing Record 12 of Set 8 | la rioja
# Processing Record 13 of Set 8 | mogadishu
# Processing Record 14 of Set 8 | capitao poco
# Processing Record 15 of Set 8 | oranjemund
# Processing Record 16 of Set 8 | itarema
# Processing Record 17 of Set 8 | deer lake
# Processing Record 18 of Set 8 | senanga
# Processing Record 19 of Set 8 | guerrero negro
# Processing Record 20 of Set 8 | simao
# Processing Record 21 of Set 8 | juybar
# Processing Record 22 of Set 8 | dinguiraye
# Processing Record 23 of Set 8 | borujerd
# Processing Record 24 of Set 8 | aloleng
# Processing Record 25 of Set 8 | talcahuano
# Processing Record 26 of Set 8 | san pedro
# Processing Record 27 of Set 8 | sitka
# Processing Record 28 of Set 8 | mount gambier
# Processing Record 29 of Set 8 | the valley
# Processing Record 30 of Set 8 | limbang
# Processing Record 31 of Set 8 | santo tomas
# Processing Record 32 of Set 8 | yar-sale
# Processing Record 33 of Set 8 | yanam
# Processing Record 34 of Set 8 | murgab
# Processing Record 35 of Set 8 | belize
# Processing Record 36 of Set 8 | karratha
# Processing Record 37 of Set 8 | maceio
# Processing Record 38 of Set 8 | alofi
# Processing Record 39 of Set 8 | lamesa
# Processing Record 40 of Set 8 | sao filipe
# Processing Record 41 of Set 8 | okhotsk
# Processing Record 42 of Set 8 | vila velha
# Processing Record 43 of Set 8 | najran
# Processing Record 44 of Set 8 | panama city
# Processing Record 45 of Set 8 | bar harbor
# Processing Record 46 of Set 8 | carutapera
# Processing Record 47 of Set 8 | okha
# Processing Record 48 of Set 8 | vilyuysk
# Processing Record 49 of Set 8 | thap than
# Processing Record 50 of Set 8 | nuevo progreso
# Processing Record 1 of Set 9 | brest
# Processing Record 2 of Set 9 | hilo
# Processing Record 3 of Set 9 | sivas
# Processing Record 4 of Set 9 | cap-aux-meules
# Processing Record 5 of Set 9 | macae
# Processing Record 6 of Set 9 | taltal
# Processing Record 7 of Set 9 | batagay-alyta
# Processing Record 8 of Set 9 | pacific grove
# Processing Record 9 of Set 9 | vagay
# Processing Record 10 of Set 9 | yulara
# Processing Record 11 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 9 | macenta
# Processing Record 13 of Set 9 | abbeville
# Processing Record 14 of Set 9 | jacqueville
# Processing Record 15 of Set 9 | magnitogorsk
# Processing Record 16 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 9 | otane
# Processing Record 18 of Set 9 | jalu
# Processing Record 19 of Set 9 | el vigia
# Processing Record 20 of Set 9 | mitsamiouli
# Processing Record 21 of Set 9 | helena
# Processing Record 22 of Set 9 | andenes
# Processing Record 23 of Set 9 | camacha
# Processing Record 24 of Set 9 | nantong
# Processing Record 25 of Set 9 | ribas do rio pardo
# Processing Record 26 of Set 9 | puerto leguizamo
# Processing Record 27 of Set 9 | port shepstone
# Processing Record 28 of Set 9 | pandan
# Processing Record 29 of Set 9 | sao jose da coroa grande
# Processing Record 30 of Set 9 | salalah
# Processing Record 31 of Set 9 | dawlatabad
# Processing Record 32 of Set 9 | ibirama
# Processing Record 33 of Set 9 | chara
# Processing Record 34 of Set 9 | suez
# Processing Record 35 of Set 9 | lagos
# Processing Record 36 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 9 | cap malheureux
# Processing Record 38 of Set 9 | ndele
# Processing Record 39 of Set 9 | oudtshoorn
# Processing Record 40 of Set 9 | muravlenko
# Processing Record 41 of Set 9 | vicksburg
# Processing Record 42 of Set 9 | lata
# Processing Record 43 of Set 9 | hvammstangi
# City not found. Skipping...
# Processing Record 44 of Set 9 | rio gallegos
# Processing Record 45 of Set 9 | yarada
# Processing Record 46 of Set 9 | silver city
# Processing Record 47 of Set 9 | pati
# Processing Record 48 of Set 9 | salinopolis
# Processing Record 49 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 9 | tchamba
# Processing Record 1 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 2 of Set 10 | svetlogorsk
# Processing Record 3 of Set 10 | cabimas
# Processing Record 4 of Set 10 | aqtobe
# Processing Record 5 of Set 10 | hoskote
# Processing Record 6 of Set 10 | jatai
# Processing Record 7 of Set 10 | galesong
# Processing Record 8 of Set 10 | hanover
# Processing Record 9 of Set 10 | gari
# Processing Record 10 of Set 10 | opuwo
# Processing Record 11 of Set 10 | mizdah
# Processing Record 12 of Set 10 | bandarbeyla
# Processing Record 13 of Set 10 | rochegda
# Processing Record 14 of Set 10 | vostok
# Processing Record 15 of Set 10 | aguimes
# Processing Record 16 of Set 10 | mantua
# Processing Record 17 of Set 10 | imbituba
# Processing Record 18 of Set 10 | cabedelo
# Processing Record 19 of Set 10 | port lincoln
# Processing Record 20 of Set 10 | caravelas
# Processing Record 21 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 10 | outlook
# Processing Record 23 of Set 10 | castro
# Processing Record 24 of Set 10 | mongoumba
# Processing Record 25 of Set 10 | ouro fino
# Processing Record 26 of Set 10 | atagay
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | tocopilla
# Processing Record 29 of Set 10 | tiznit
# Processing Record 30 of Set 10 | mogzon
# Processing Record 31 of Set 10 | krasnoselkup
# Processing Record 32 of Set 10 | adelanto
# Processing Record 33 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 10 | cortez
# Processing Record 35 of Set 10 | avigliana
# Processing Record 36 of Set 10 | fatick
# Processing Record 37 of Set 10 | samarai
# Processing Record 38 of Set 10 | navirai
# Processing Record 39 of Set 10 | atambua
# Processing Record 40 of Set 10 | lockhart
# Processing Record 41 of Set 10 | hearst
# Processing Record 42 of Set 10 | sao felix do xingu
# Processing Record 43 of Set 10 | sao geraldo do araguaia
# Processing Record 44 of Set 10 | charters towers
# Processing Record 45 of Set 10 | boyuibe
# Processing Record 46 of Set 10 | semporna
# Processing Record 47 of Set 10 | delijan
# Processing Record 48 of Set 10 | soyo
# Processing Record 49 of Set 10 | constitucion
# Processing Record 50 of Set 10 | rawah
# Processing Record 1 of Set 11 | kharan
# Processing Record 2 of Set 11 | timbiqui
# Processing Record 3 of Set 11 | itaueira
# Processing Record 4 of Set 11 | sherghati
# Processing Record 5 of Set 11 | shibarghan
# City not found. Skipping...
# Processing Record 6 of Set 11 | fort nelson
# Processing Record 7 of Set 11 | mao
# Processing Record 8 of Set 11 | vytegra
# Processing Record 9 of Set 11 | shu
# Processing Record 10 of Set 11 | dudinka
# Processing Record 11 of Set 11 | uruzgan
# Processing Record 12 of Set 11 | ust-tsilma
# Processing Record 13 of Set 11 | esil
# Processing Record 14 of Set 11 | bosaso
# Processing Record 15 of Set 11 | high rock
# Processing Record 16 of Set 11 | gobabis
# Processing Record 17 of Set 11 | rio do sul
# Processing Record 18 of Set 11 | luba
# Processing Record 19 of Set 11 | irbit
# Processing Record 20 of Set 11 | komsomolskiy
# Processing Record 21 of Set 11 | kloulklubed
# Processing Record 22 of Set 11 | vestmannaeyjar
# Processing Record 23 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 11 | tawau
# Processing Record 25 of Set 11 | birao
# Processing Record 26 of Set 11 | antalaha
# Processing Record 27 of Set 11 | alice springs
# Processing Record 28 of Set 11 | havelock
# Processing Record 29 of Set 11 | khandyga
# Processing Record 30 of Set 11 | tiverton
# Processing Record 31 of Set 11 | abu dhabi
# Processing Record 32 of Set 11 | tena
# Processing Record 33 of Set 11 | locri
# Processing Record 34 of Set 11 | las palmas
# Processing Record 35 of Set 11 | marawi
# Processing Record 36 of Set 11 | bethel
# Processing Record 37 of Set 11 | waddan
# Processing Record 38 of Set 11 | coquimbo
# Processing Record 39 of Set 11 | mahibadhoo
# Processing Record 40 of Set 11 | awjilah
# Processing Record 41 of Set 11 | petlawad
# Processing Record 42 of Set 11 | terney
# Processing Record 43 of Set 11 | emerald
# Processing Record 44 of Set 11 | jeremie
# Processing Record 45 of Set 11 | saint-pierre
# Processing Record 46 of Set 11 | redmond
# Processing Record 47 of Set 11 | belyy yar
# Processing Record 48 of Set 11 | huanan
# Processing Record 49 of Set 11 | tuatapere
# Processing Record 50 of Set 11 | salym
# Processing Record 1 of Set 12 | olavarria
# Processing Record 2 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 12 | kokopo
# Processing Record 4 of Set 12 | port-cartier
# Processing Record 5 of Set 12 | mandurah
# Processing Record 6 of Set 12 | arteaga
# Processing Record 7 of Set 12 | bodden town
# Processing Record 8 of Set 12 | altay
# Processing Record 9 of Set 12 | tomatlan
# Processing Record 10 of Set 12 | puertollano
# Processing Record 11 of Set 12 | pridonskoy
# Processing Record 12 of Set 12 | novooleksiyivka
# Processing Record 13 of Set 12 | annau
# Processing Record 14 of Set 12 | yala
# Processing Record 15 of Set 12 | clarence town
# Processing Record 16 of Set 12 | coahuayana
# Processing Record 17 of Set 12 | methoni
# Processing Record 18 of Set 12 | navalmoral de la mata
# Processing Record 19 of Set 12 | margate
# Processing Record 20 of Set 12 | safranbolu
# Processing Record 21 of Set 12 | klaksvik
# Processing Record 22 of Set 12 | duz
# City not found. Skipping...
# Processing Record 23 of Set 12 | oksfjord
# Processing Record 24 of Set 12 | okato
# Processing Record 25 of Set 12 | kabo
# Processing Record 26 of Set 12 | shieli
# Processing Record 27 of Set 12 | mezhdurechenskiy
# Processing Record 28 of Set 12 | luwingu
# Processing Record 29 of Set 12 | kayasula
# Processing Record 30 of Set 12 | sainte-maxime
# Processing Record 31 of Set 12 | te anau
# Processing Record 32 of Set 12 | flinders
# Processing Record 33 of Set 12 | male
# Processing Record 34 of Set 12 | panorama
# Processing Record 35 of Set 12 | tara
# Processing Record 36 of Set 12 | bilgi
# Processing Record 37 of Set 12 | maningrida
# Processing Record 38 of Set 12 | indiana
# Processing Record 39 of Set 12 | vasudevanallur
# Processing Record 40 of Set 12 | half moon bay
# Processing Record 41 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 12 | korla
# Processing Record 43 of Set 12 | gorontalo
# Processing Record 44 of Set 12 | ayan
# Processing Record 45 of Set 12 | moron
# Processing Record 46 of Set 12 | george
# Processing Record 47 of Set 12 | ler
# Processing Record 48 of Set 12 | odesskoye
# Processing Record 49 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 50 of Set 12 | sabang
# Processing Record 1 of Set 13 | abu kamal
# Processing Record 2 of Set 13 | xihe
# Processing Record 3 of Set 13 | orlik
# Processing Record 4 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 13 | walvis bay
# Processing Record 6 of Set 13 | presidencia roque saenz pena
# Processing Record 7 of Set 13 | dawei
# Processing Record 8 of Set 13 | urcos
# Processing Record 9 of Set 13 | ponta delgada
# Processing Record 10 of Set 13 | piacabucu
# Processing Record 11 of Set 13 | victor harbor
# Processing Record 12 of Set 13 | santa cruz
# Processing Record 13 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 14 of Set 13 | epiniana
# Processing Record 15 of Set 13 | aksarka
# Processing Record 16 of Set 13 | portland
# Processing Record 17 of Set 13 | minyar
# Processing Record 18 of Set 13 | kayerkan
# Processing Record 19 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 20 of Set 13 | dunda
# Processing Record 21 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 22 of Set 13 | taoudenni
# Processing Record 23 of Set 13 | seymchan
# Processing Record 24 of Set 13 | sweetwater
# Processing Record 25 of Set 13 | arlit
# Processing Record 26 of Set 13 | roma
# Processing Record 27 of Set 13 | zhongshu
# Processing Record 28 of Set 13 | ucluelet
# Processing Record 29 of Set 13 | collecchio
# Processing Record 30 of Set 13 | ostrovnoy
# Processing Record 31 of Set 13 | hasaki
# Processing Record 32 of Set 13 | mason city
# Processing Record 33 of Set 13 | naze
# Processing Record 34 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 13 | cayenne
# Processing Record 36 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 37 of Set 13 | tartagal
# Processing Record 38 of Set 13 | clearwater
# Processing Record 39 of Set 13 | guekedou
# City not found. Skipping...
# Processing Record 40 of Set 13 | myra
# Processing Record 41 of Set 13 | egvekinot
# Processing Record 42 of Set 13 | sola
# Processing Record 43 of Set 13 | rocha
# Processing Record 44 of Set 13 | zeya
# Processing Record 45 of Set 13 | krasnogorodsk
# Processing Record 46 of Set 13 | puerto cortes
# City not found. Skipping...
# Processing Record 47 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 13 | road town
# Processing Record 50 of Set 13 | basavakalyan
# Processing Record 1 of Set 14 | waitati
# Processing Record 2 of Set 14 | praia da vitoria
# Processing Record 3 of Set 14 | kudahuvadhoo
# Processing Record 4 of Set 14 | meulaboh
# Processing Record 5 of Set 14 | kyra
# Processing Record 6 of Set 14 | muhos
# Processing Record 7 of Set 14 | channel-port aux basques
# Processing Record 8 of Set 14 | fianga
# City not found. Skipping...
# Processing Record 9 of Set 14 | anadyr
# Processing Record 10 of Set 14 | marsa matruh
# Processing Record 11 of Set 14 | attur
# Processing Record 12 of Set 14 | hervey bay
# Processing Record 13 of Set 14 | adrar
# Processing Record 14 of Set 14 | himeji
# Processing Record 15 of Set 14 | kaspiyskiy
# Processing Record 16 of Set 14 | grand gaube
# Processing Record 17 of Set 14 | hammerfest
# Processing Record 18 of Set 14 | yeniseysk
# Processing Record 19 of Set 14 | teguldet
# Processing Record 20 of Set 14 | vikhorevka
# Processing Record 21 of Set 14 | tonosho
# Processing Record 22 of Set 14 | progreso
# Processing Record 23 of Set 14 | berlevag
# Processing Record 24 of Set 14 | camabatela
# Processing Record 25 of Set 14 | paso de patria
# Processing Record 26 of Set 14 | coihaique
# Processing Record 27 of Set 14 | klamath falls
# Processing Record 28 of Set 14 | ballina
# Processing Record 29 of Set 14 | awbari
# Processing Record 30 of Set 14 | santa barbara
# Processing Record 31 of Set 14 | casa grande
# Processing Record 32 of Set 14 | grand baie
# Processing Record 33 of Set 14 | eydhafushi
# Processing Record 34 of Set 14 | san jeronimo
# Processing Record 35 of Set 14 | grindavik
# Processing Record 36 of Set 14 | visnes
# Processing Record 37 of Set 14 | misratah
# Processing Record 38 of Set 14 | salisbury
# Processing Record 39 of Set 14 | key west
# Processing Record 40 of Set 14 | bhinmal
# Processing Record 41 of Set 14 | shubarshi
# Processing Record 42 of Set 14 | santa pola
# Processing Record 43 of Set 14 | adeje
# Processing Record 44 of Set 14 | camopi
# Processing Record 45 of Set 14 | takab
# Processing Record 46 of Set 14 | chapais
# Processing Record 47 of Set 14 | kurilsk
# Processing Record 48 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 14 | kamenka
# Processing Record 50 of Set 14 | denpasar
# Processing Record 1 of Set 15 | dubrovnik
# Processing Record 2 of Set 15 | scurtu mare
# Processing Record 3 of Set 15 | latung
# Processing Record 4 of Set 15 | upata
# Processing Record 5 of Set 15 | isangel
# Processing Record 6 of Set 15 | georgiyevka
# Processing Record 7 of Set 15 | manbij
# Processing Record 8 of Set 15 | ruangwa
# Processing Record 9 of Set 15 | gao
# Processing Record 10 of Set 15 | porto walter
# Processing Record 11 of Set 15 | sinyavskoye
# Processing Record 12 of Set 15 | tapes
# Processing Record 13 of Set 15 | sattahip
# Processing Record 14 of Set 15 | nyurba
# Processing Record 15 of Set 15 | tabory
# Processing Record 16 of Set 15 | bowmore
# Processing Record 17 of Set 15 | kirakira
# Processing Record 18 of Set 15 | chicama
# Processing Record 19 of Set 15 | ayagoz
# Processing Record 20 of Set 15 | viedma
# Processing Record 21 of Set 15 | lasa
# Processing Record 22 of Set 15 | sembakung
# Processing Record 23 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 24 of Set 15 | shahrud
# Processing Record 25 of Set 15 | monywa
# Processing Record 26 of Set 15 | porto novo
# Processing Record 27 of Set 15 | aswan
# Processing Record 28 of Set 15 | yamethin
# Processing Record 29 of Set 15 | zhirnovsk
# Processing Record 30 of Set 15 | saryg-sep
# Processing Record 31 of Set 15 | salinas
# Processing Record 32 of Set 15 | necochea
# Processing Record 33 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 15 | beidao
# Processing Record 35 of Set 15 | udachnyy
# Processing Record 36 of Set 15 | itapaci
# Processing Record 37 of Set 15 | puerto del rosario
# Processing Record 38 of Set 15 | dunedin
# Processing Record 39 of Set 15 | himora
# City not found. Skipping...
# Processing Record 40 of Set 15 | monaragala
# Processing Record 41 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 15 | rio branco
# Processing Record 43 of Set 15 | kungurtug
# Processing Record 44 of Set 15 | blagoyevo
# Processing Record 45 of Set 15 | abalak
# Processing Record 46 of Set 15 | bam
# Processing Record 47 of Set 15 | alexandria
# Processing Record 48 of Set 15 | svolvaer
# Processing Record 49 of Set 15 | le port
# Processing Record 50 of Set 15 | krasnoborsk
# Processing Record 1 of Set 16 | mogapi
# Processing Record 2 of Set 16 | goshen
# Processing Record 3 of Set 16 | tiarei
# Processing Record 4 of Set 16 | mandalgovi
# Processing Record 5 of Set 16 | soe
# Processing Record 6 of Set 16 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 16 | boo
# Processing Record 8 of Set 16 | buluang
# Processing Record 9 of Set 16 | aklavik
# Processing Record 10 of Set 16 | ghotki
# Processing Record 11 of Set 16 | lusaka
# Processing Record 12 of Set 16 | pimentel
# Processing Record 13 of Set 16 | muros
# Processing Record 14 of Set 16 | lorengau
# Processing Record 15 of Set 16 | burias
# Processing Record 16 of Set 16 | xuanzhou
# Processing Record 17 of Set 16 | kishi
# Processing Record 18 of Set 16 | nambucca heads
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Smithers  54.7804 -127.1743     59.32        67          75
# 1         Rikitea -23.1203 -134.9692     71.42        64          98
# 2         Semirom  31.4167   51.5667     72.25        27          42
# 3    San Patricio  28.0170  -97.5169     95.54        44           0
# 4         Guatire  10.4762  -66.5427     77.50        94          96
# 5      Banda Aceh   5.5577   95.3222     80.44        79         100
# 6          Avarua -21.2078 -159.7750     77.05        73           2
# 7          Barrow  71.2906 -156.7887     37.42        87          90
# 8    Saint George  37.1041 -113.5841     99.79        32           1
# 9  Saint-Philippe -21.3585   55.7679     67.59        72          33
#
#    Wind Speed Country Current Description
# 0        3.44      CA          light rain
# 1       16.33      PF     overcast clouds
# 2        3.53      IR    scattered clouds
# 3       17.90      US           clear sky
# 4        3.04      VE     overcast clouds
# 5       12.66      ID     overcast clouds
# 6        6.91      CK           clear sky
# 7       16.11      US          light rain
# 8       11.01      US           clear sky
# 9        7.67      RE    scattered clouds

# %%
# import the dataframe to a CSV
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
